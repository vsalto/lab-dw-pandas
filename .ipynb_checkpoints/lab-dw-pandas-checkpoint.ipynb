# %% [markdown]
# # Lab | Pandas

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# The data includes information such as customer ID, state, gender, education, income, and other variables that can be used to perform various analyses.
#
# Throughout the lab, we will be using the pandas library in Python to manipulate and analyze the data. Pandas is a powerful library that provides various data manipulation and analysis tools, including the ability to load and manipulate data from a variety of sources, including CSV files.

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.

# %% [markdown]
# External Resources: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %% [markdown]
# ## Challenge 1: Understanding the data
#
# In this challenge, you will use pandas to explore a given dataset. Your task is to gain a deep understanding of the data by analyzing its characteristics, dimensions, and statistical properties.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
customer_df = pd.read_csv(url)
customer_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Identify the dimensions of the dataset by determining the number of rows and columns it contains.
print(f'The dataframe contains {customer_df.shape[0]} rows and {customer_df.shape[1]} columns')
# Out:
# The dataframe contains 4008 rows and 11 columns

# %%
# Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. 
# You should also provide suggestions for fixing any incorrect data types.
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
print(f' The Customer Lifetime Value is a percentage.  % needs to be removed to be considred as float')
# Out:
#  The Customer Lifetime Value is a percentage.  % needs to be removed to be considred as float

# %%
customer_df['Customer Lifetime Value'] = customer_df['Customer Lifetime Value'].str.rstrip('%').astype('float')
customer_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   float64
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 344.6+ KB

# %%
# Identify the number of unique values for each column and determine which columns appear to be categorical. 
# You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
customer_df.nunique()
# Out:
# Customer                     1071
# ST                              8
# GENDER                          5
# Education                       6
# Customer Lifetime Value      1027
# Income                        774
# Monthly Premium Auto          132
# Number of Open Complaints       6
# Policy Type                     3
# Vehicle Class                   6
# Total Claim Amount            761
# dtype: int64

# %%
categorical_df = customer_df [['Customer', 'ST', 'GENDER', 'Education', 'Policy Type', 'Vehicle Class']]
display(categorical_df)
print('Unique values in Customer')
print(categorical_df['Customer'].unique())
print(categorical_df['Customer'].nunique())
print()
print('Unique values in ST')
print(categorical_df['ST'].unique())
print(categorical_df['ST'].nunique())
print()
print('Unique values in GENDER')
print(categorical_df['GENDER'].unique())
print(categorical_df['GENDER'].nunique())
print()
print('Unique values in Education')
print(categorical_df['Education'].unique())
print(categorical_df['Education'].nunique())
print()
print('Unique values in Policy Type')
print(categorical_df['Policy Type'].unique())
print(categorical_df['Policy Type'].nunique())
print()
print('Unique values in Vehicle Class')
print(categorical_df['Vehicle Class'].unique())
print(categorical_df['Vehicle Class'].nunique())
print()
# Out:
#      Customer          ST GENDER             Education     Policy Type  \
# 0     RB50392  Washington    NaN                Master   Personal Auto
# 1     QZ44356     Arizona      F              Bachelor   Personal Auto
# 2     AI49188      Nevada      F              Bachelor   Personal Auto
# 3     WW63253  California      M              Bachelor  Corporate Auto
# 4     GA49547  Washington      M  High School or Below   Personal Auto
# ...       ...         ...    ...                   ...             ...
# 4003      NaN         NaN    NaN                   NaN             NaN
# 4004      NaN         NaN    NaN                   NaN             NaN
# 4005      NaN         NaN    NaN                   NaN             NaN
# 4006      NaN         NaN    NaN                   NaN             NaN
# 4007      NaN         NaN    NaN                   NaN             NaN
#
#       Vehicle Class
# 0     Four-Door Car
# 1     Four-Door Car
# 2      Two-Door Car
# 3               SUV
# ...

# %%
numerical_df = customer_df [['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Total Claim Amount']]
display(numerical_df)
print()
print('Range in values of Customer Lifetime Value')
print(f"Max: {numerical_df['Customer Lifetime Value'].max()} Min: {numerical_df['Customer Lifetime Value'].min()}" )
print()
print('Range in values of Income')
print(f"Max: {numerical_df['Income'].max()} Min: {numerical_df['Income'].min()}" )
print()
print('Range in values of Monthly Premium Auto')
print(f"Max: {numerical_df['Monthly Premium Auto'].max()} Min: {numerical_df['Monthly Premium Auto'].min()}" )
print()
print('Range in values of Total Claim Amount')
print(f"Max: {numerical_df['Total Claim Amount'].max()} Min: {numerical_df['Total Claim Amount'].min()}" )
# Out:
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# 3                   764586.18      0.0                 106.0
# 4                   536307.65  36357.0                  68.0
# ...                       ...      ...                   ...
# 4003                      NaN      NaN                   NaN
# 4004                      NaN      NaN                   NaN
# 4005                      NaN      NaN                   NaN
# 4006                      NaN      NaN                   NaN
# 4007                      NaN      NaN                   NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# ...

# %%
# Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution 
# of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
statistics = numerical_df.describe()
display(statistics)

print()
print('Mode value of the numerical data')
print('---------------------------------')
display(numerical_df.mode())

print()
print('Median value of the numerical data')
print('---------------------------------')
print(numerical_df.median())
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             1.068000e+03   1071.000000           1071.000000
# mean              7.936903e+05  39295.701214            193.234360
# std               6.434784e+05  30469.427060           1601.190369
# min               2.004351e+05      0.000000             61.000000
# 25%               4.034080e+05  14072.000000             68.000000
# 50%               5.881742e+05  36234.000000             83.000000
# 75%               8.962872e+05  64631.000000            109.500000
# max               5.816655e+06  99960.000000          35354.000000
#
#        Total Claim Amount
# count         1071.000000
# mean           404.986909
# std            293.027260
# min              0.382107
# 25%            202.157702
# 50%            354.729129
# 75%            532.800000
# max           2893.239678
# Mode value of the numerical data
# ---------------------------------
# ...

# %%
categorical_df
# Out:
#      Customer          ST GENDER             Education     Policy Type  \
# 0     RB50392  Washington    NaN                Master   Personal Auto
# 1     QZ44356     Arizona      F              Bachelor   Personal Auto
# 2     AI49188      Nevada      F              Bachelor   Personal Auto
# 3     WW63253  California      M              Bachelor  Corporate Auto
# 4     GA49547  Washington      M  High School or Below   Personal Auto
# ...       ...         ...    ...                   ...             ...
# 4003      NaN         NaN    NaN                   NaN             NaN
# 4004      NaN         NaN    NaN                   NaN             NaN
# 4005      NaN         NaN    NaN                   NaN             NaN
# 4006      NaN         NaN    NaN                   NaN             NaN
# 4007      NaN         NaN    NaN                   NaN             NaN
#
#       Vehicle Class
# 0     Four-Door Car
# 1     Four-Door Car
# 2      Two-Door Car
# 3               SUV
# ...

# %%
# Compute summary statistics for categorical columns and providing your conclusions based on these statistics.
print()
print('Frequency of values in Customer')
print('---------------------------------')
print(categorical_df['Customer'].value_counts())
print()
print('Frequency of values in ST')
print('---------------------------------')
print(categorical_df['ST'].value_counts())
print()
print('Frequency of values in GENDER')
print('---------------------------------')
print(categorical_df['GENDER'].value_counts())
print()
print('Frequency of values in Education')
print('---------------------------------')
print(categorical_df['Education'].value_counts())
print()
print('Frequency of values in Policy Type')
print('---------------------------------')
print(categorical_df['Policy Type'].value_counts())
print()
print('Frequency of values in Vehicle Class')
print('---------------------------------')
print(categorical_df['Vehicle Class'].value_counts())
# Out:
# Frequency of values in Customer
# ---------------------------------
# Customer
# RB50392    1
# HJ15383    1
# AO74776    1
# HQ82233    1
# OL72737    1
#           ..
# RO26085    1
# ES57969    1
# JK55587    1
# RN97635    1
# MY31220    1
# Name: count, Length: 1071, dtype: int64
#
# Frequency of values in ST
# ---------------------------------
# ST
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64
#
# Frequency of values in GENDER
# ---------------------------------
# GENDER
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: count, dtype: int64
#
# Frequency of values in Education
# ---------------------------------
# Education
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# ...

# %% [markdown]
# ## Challenge 2: analyzing the data

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The marketing team wants to know the top 5 less common customer locations. Create a pandas Series object that contains the customer locations and their frequencies, and then retrieve the top 5 less common locations in ascending order.

# %%
customer_location = categorical_df['ST'].value_counts()
print(customer_location)
print()
print('top 5 less common locations')
print('---------------------------------')
print(customer_location.index[-6:-1])
# Out:
# ST
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64
#
# top 5 less common locations
# ---------------------------------
# Index(['Arizona', 'Cali', 'Nevada', 'Washington', 'WA'], dtype='object', name='ST')

# %% [markdown]
# ### Exercise 2
#
# The sales team wants to know the total number of policies sold for each type of policy. Create a pandas Series object that contains the policy types and their total number of policies sold, and then retrieve the policy type with the highest number of policies sold.

# %% [markdown]
# *Hint:*
# - *Using value_counts() method simplifies this analysis.*
# - *Futhermore, there is a method that returns the index of the maximum value in a column or row.*

# %%
customer_policy = categorical_df['Policy Type'].value_counts()
print(customer_policy)
print()
print('Top Policy type')
print('---------------------------------')
print(customer_policy.idxmax())
# Out:
# Policy Type
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: count, dtype: int64
#
# Top Policy type
# ---------------------------------
# Personal Auto

# %% [markdown]
# ### Exercise 3
#
# The sales team wants to know if customers with Personal Auto have a lower income than those with Corporate Auto. How does the average income compare between the two policy types?

# %% [markdown]
# - Use *loc* to create two dataframes: one containing only Personal Auto policies and one containing only Corporate Auto policies.
# - Calculate the average income for each policy.
# - Print the results.

# %%
customers_PA = customer_df.loc[customer_df['Policy Type'] == 'Personal Auto']
customers_PA
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1065  XD85577        Cali      M              Bachelor
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1070  MY31220  California      F               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
customers_CA = customer_df.loc[customer_df['Policy Type'] == 'Corporate Auto']
customers_CA
# Out:
#      Customer          ST GENDER             Education  \
# 3     WW63253  California      M              Bachelor
# 6     XZ87318      Oregon      F               College
# 7     CF85061     Arizona      M                Master
# 8     DY87989      Oregon      M              Bachelor
# 12    DP39365  California    NaN                Master
# ...       ...         ...    ...                   ...
# 1045  WZ31900      Oregon      F              Bachelor
# 1050  BJ53923     Arizona      M  High School or Below
# 1052  FB23788      Oregon      M  High School or Below
# 1056  PI47776      Oregon      F              Bachelor
# 1059  YG44474      Oregon      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 3                   764586.18      0.0                 106.0
# 6                   538089.86  55350.0                  67.0
# 7                   721610.03      0.0                 101.0
# ...

# %%
incomePA = customers_PA['Income'].mean()
print(f'Customers with Personal Auto policy have in average {incomePA} income')
print()
incomeCA = customers_CA['Income'].mean()
print(f'Customers with Personal Auto policy have in average {incomeCA} income')
print()
if incomePA < incomeCA:
    print('Customers with Personal Auto policy have lower income in average than customers with Corporate Auto policy.')
else:
    print('Customers with Personal Auto policy have higher income in average than customers with Corporate Auto policy.')
# Out:
# Customers with Personal Auto policy have in average 38180.69871794872 income
#
# Customers with Personal Auto policy have in average 41390.31196581197 income
#
# Customers with Personal Auto policy have lower income in average than customers with Corporate Auto policy.

# %% [markdown]
# ### Bonus: Exercise 4

# %% [markdown]
# Your goal is to identify customers with a high policy claim amount.
#
# Instructions:
#
# - Review again the statistics for total claim amount to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount data.

# %% [markdown]
# *Note: When analyzing data, we often want to focus on certain groups of values to gain insights. Percentiles are a useful tool to help us define these groups. A percentile is a measure that tells us what percentage of values in a dataset are below a certain value. For example, the 75th percentile represents the value below which 75% of the data falls. Similarly, the 25th percentile represents the value below which 25% of the data falls. When we talk about the top 25%, we are referring to the values that fall above the 75th percentile, which represent the top quarter of the data. On the other hand, when we talk about the bottom 25%, we are referring to the values that fall below the 25th percentile, which represent the bottom quarter of the data. By focusing on these groups, we can identify patterns and trends that may be useful for making decisions and taking action.*
#
# *Hint: look for a method that gives you the percentile or quantile 0.75 and 0.25 for a Pandas Series.*

# %% [markdown]
# *Hint 2: check `Boolean selection according to the values of a single column` in https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9*

# %%
customer_df['Total Claim Amount']
# Out:
# 0          2.704934
# 1       1131.464935
# 2        566.472247
# 3        529.881344
# 4         17.269323
#            ...
# 4003            NaN
# 4004            NaN
# 4005            NaN
# 4006            NaN
# 4007            NaN
# Name: Total Claim Amount, Length: 4008, dtype: float64

# %%
customer_df['Total Claim Amount'].describe()
# Out:
# count    1071.000000
# mean      404.986909
# std       293.027260
# min         0.382107
# 25%       202.157702
# 50%       354.729129
# 75%       532.800000
# max      2893.239678
# Name: Total Claim Amount, dtype: float64

# %%
customers_claim75 = customer_df.loc[customer_df['Total Claim Amount'] > np.nanpercentile(customer_df['Total Claim Amount'], 75)]
customers_claim75
# Out:
#      Customer          ST GENDER Education  Customer Lifetime Value   Income  \
# 1     QZ44356     Arizona      F  Bachelor                697953.59      0.0
# 2     AI49188      Nevada      F  Bachelor               1288743.17  48767.0
# 17    OE15005        Cali    NaN   College                394524.16  28855.0
# 23    TZ98966      Nevada    NaN  Bachelor                245019.10      0.0
# 26    US89481  California    NaN  Bachelor                394637.21      0.0
# ...       ...         ...    ...       ...                      ...      ...
# 1059  YG44474      Oregon      M   College               1401472.13  54193.0
# 1061  RY92647        Cali      F  Bachelor               1050677.17      0.0
# 1068  GS98873     Arizona      F  Bachelor                323912.47  16061.0
# 1069  CW49887  California      F    Master                462680.11  79487.0
# 1070  MY31220  California      F   College                899704.02  54230.0
#
# ...

# %%
customers_claim75.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             2.640000e+02    264.000000            264.000000
# mean              9.086868e+05  23677.344697            165.193182
# std               6.387678e+05  27013.483721            623.930992
# min               2.287597e+05      0.000000             63.000000
# 25%               4.723958e+05      0.000000             99.000000
# 50%               7.781768e+05  18807.000000            114.000000
# 75%               1.054430e+06  42423.750000            133.250000
# max               3.844586e+06  99316.000000          10202.000000
#
#        Total Claim Amount
# count          264.000000
# mean           782.228263
# std            292.751640
# min            537.600000
# 25%            606.521741
# 50%            679.597985
# 75%            851.400000
# max           2893.239678
